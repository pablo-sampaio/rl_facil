# %% [markdown]
# # Ações Contínuas com Stable Baselines3
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/pablo-sampaio/rl_facil/blob/main/cap09/cap09-3-DDPG-stablebaselines.ipynb)
#
# Vamos usar os algoritmo **DDPG**, **TD3** e **SAC** neste Google Colab.
#
# Referências:
# - Stable-Baselines3: https://github.com/DLR-RM/stable-baselines3
# - Documentação: https://stable-baselines3.readthedocs.io/en/master/guide/rl.html

# %% [markdown]
# ## 1 - Configurações necessárias

# %% [markdown]
# ### 1.1 Instalação de pacotes

# %%
import sys
from IPython.display import clear_output

IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
    # !apt-get install ffmpeg freeglut3-dev xvfb  # For visualization
    # !pip install "stable-baselines3[extra]==2.0.0"
    #clear_output()

# %%
# !mkdir log_dir
# Out:
# J� existe uma subpasta ou um arquivo log_dir.

# %% [markdown]
# ### 1.2 Para salvar vídeo

# %%
if IN_COLAB:
    # Set up fake display; otherwise rendering will fail
    import os
    os.system("Xvfb :1 -screen 0 1024x768x24 &")
    os.environ['DISPLAY'] = ':1'

# %% [markdown]
# A gravação é feita com o wrapper [VecVideoRecorder](https://stable-baselines.readthedocs.io/en/master/guide/vec_envs.html#vecvideorecorder).

# %%
from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv

def record_video(env_id, model, video_length=500, prefix='', video_folder='videos/'):
  """
  :param env_id: (str)
  :param model: (RL model)
  :param video_length: (int)
  :param prefix: (str)
  :param video_folder: (str)
  """
  eval_env = DummyVecEnv([lambda: gym.make(env_id, render_mode="rgb_array")])
  # Start the video at step=0 and record the given number of steps
  eval_env = VecVideoRecorder(eval_env, video_folder=video_folder,
                              record_video_trigger=lambda step: step == 0, video_length=video_length,
                              name_prefix=prefix)

  obs = eval_env.reset()
  for _ in range(video_length):
    action, _ = model.predict(obs)
    obs, _, _, _ = eval_env.step(action)

  # Close the video recorder
  eval_env.close()

# %%
import base64
from pathlib import Path

from IPython import display as ipythondisplay

def show_videos(video_path='', prefix=''):
  """
  Taken from https://github.com/eleurent/highway-env

  :param video_path: (str) Path to the folder containing videos
  :param prefix: (str) Filter the video, showing only the only starting with this prefix
  """
  html = []
  for mp4 in Path(video_path).glob("{}*.mp4".format(prefix)):
      video_b64 = base64.b64encode(mp4.read_bytes())
      html.append('''<video alt="{}" autoplay
                    loop controls style="height: 400px;">
                    <source src="data:video/mp4;base64,{}" type="video/mp4" />
                </video>'''.format(mp4, video_b64.decode('ascii')))
  ipythondisplay.display(ipythondisplay.HTML(data="<br>".join(html)))

# %% [markdown]
# ### 1.3 Imports

# %%
import gymnasium as gym
import numpy as np

import tensorboard
# %load_ext tensorboard

import stable_baselines3
stable_baselines3.__version__
# Out:
# '2.1.0'

# %%
from stable_baselines3 import DDPG, TD3, SAC
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise

# %% [markdown]
# ## 2 - Ativa Tensorboard

# %% [markdown]
# Acompanhe, principalmente, o indicador `ep_rew_mean`, que é a **recompensa média por episódio** (= **retorno médio**).
#
# Também vale a pena comparar diferentes algoritmos quanto ao "tempo de relógio": escolha `RELATIVE` para o eixo horizontal.

# %%
# %tensorboard --logdir log_dir
# Out:
# Reusing TensorBoard on port 6006 (pid 20092), started 2 days, 1:20:16 ago. (Use '!kill 20092' to kill it.)
#       <iframe id="tensorboard-frame-b4a0787cff214613" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-b4a0787cff214613");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## 3 - Cria e Treina um Agente

# %%
# Algumas opções de ambientes com ações contínuas:
# 'Pendulum-v1', 'LunarLanderContinuous-v2', 'MountainCarContinuous-v0', 'BipedalWalker-v3'
ENVIRONMENT_ID = "Pendulum-v1"

env = gym.make(ENVIRONMENT_ID)

# The noise objects for DDPG and TD3
n_actions = env.action_space.shape[-1]
action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))
policy_kwargs = None

# %% [markdown]
# Descomente o código abaixo, se quiser definir o números de nós por camada intermediária das redes que representam política **pi** (chave `pi` do dicionário) e do crítico **Q** (chave `qf`).
#
# Mais informações: https://stable-baselines.readthedocs.io/en/master/guide/custom_policy.html.

# %%
# Ator com duas camadas: de 128 e 256 unidades / Crítico com duas camadas de 256 unidades cada
#policy_kwargs = dict( net_arch=dict(pi=[128, 256], qf=[256, 256]) )

# %% [markdown]
# Escolha um dos algoritmos abaixo descomentando a linha correspondente. Mais informações:
# - **DDPG**: https://stable-baselines3.readthedocs.io/en/master/modules/ddpg.html
# - **TD3**: https://stable-baselines3.readthedocs.io/en/master/modules/td3.html
# - **SAC**: https://stable-baselines3.readthedocs.io/en/master/modules/sac.html

# %%
# Cria o agente
model = DDPG("MlpPolicy", env, policy_kwargs=policy_kwargs, action_noise=action_noise, tensorboard_log="log_dir", verbose=1, device="auto")
#model = TD3("MlpPolicy", env, policy_kwargs=policy_kwargs, action_noise=action_noise, tensorboard_log="log_dir", verbose=1)
#model = SAC("MlpPolicy", env, policy_kwargs=policy_kwargs, tensorboard_log="log_dir", verbose=1)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# Avalia o agente antes de treinado
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=100)
print(f"Retorno médio: {mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# c:\Users\pablo\.conda\envs\rl23x\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Retorno médio: -1595.31 +/- 174.87

# %%
# Aplica o treinamento
model.learn(total_timesteps=20_000, log_interval=10)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -625     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 61       |
# |    time_elapsed    | 129      |
# |    total_timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | 76.9     |
# |    critic_loss     | 2.21     |
# |    ent_coef        | 0.167    |
# |    ent_coef_loss   | -0.409   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7899     |
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\pablo\Documents\Projetos\pablo-sampaio\rl_facil\cap09\cap09-3-DDPG-stablebaselines.ipynb Cell 24 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/pablo/Documents/Projetos/pablo-sampaio/rl_facil/cap09/cap09-3-DDPG-stablebaselines.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> # Aplica o treinamento
# ----> <a href='vscode-notebook-cell:/c%3A/Users/pablo/Documents/Projetos/pablo-sampaio/rl_facil/cap09/cap09-3-DDPG-stablebaselines.ipynb#X32sZmlsZQ%3D%3D?line=1'>2</a> model.learn(total_timesteps=20_000, log_interval=10)
#
# File c:\Users\pablo\.conda\envs\rl23x\lib\site-packages\stable_baselines3\sac\sac.py:307, in SAC.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     298 def learn(
#     299     self: SelfSAC,
#     300     total_timesteps: int,
#    (...)
#     305     progress_bar: bool = False,
#     306 ) -> SelfSAC:
# --> 307     return super().learn(
#     308         total_timesteps=total_timesteps,
#     309         callback=callback,
#     310         log_interval=log_interval,
#     311         tb_log_name=tb_log_name,
#     312         reset_num_timesteps=reset_num_timesteps,
#     313         progress_bar=progress_bar,
#     314     )
#
# File c:\Users\pablo\.conda\envs\rl23x\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:331, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     329         # Special case when the user passes `gradient_steps=0`
#     330         if gradient_steps > 0:
# --> 331             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     333 callback.on_training_end()
#     335 return self
#
# File c:\Users\pablo\.conda\envs\rl23x\lib\site-packages\stable_baselines3\sac\sac.py:273, in SAC.train(self, gradient_steps, batch_size)
#     268 self.critic.optimizer.step()
#     270 # Compute actor loss
#     271 # Alternative: actor_loss = th.mean(log_prob - qf1_pi)
#     272 # Min over all critic networks
# --> 273 q_values_pi = th.cat(self.critic(replay_data.observations, actions_pi), dim=1)
#     274 min_qf_pi, _ = th.min(q_values_pi, dim=1, keepdim=True)
#     275 actor_loss = (ent_coef * log_prob - min_qf_pi).mean()
#
# File c:\Users\pablo\.conda\envs\rl23x\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\pablo\.conda\envs\rl23x\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\pablo\.conda\envs\rl23x\lib\site-packages\stable_baselines3\common\policies.py:937, in ContinuousCritic.forward(self, obs, actions)
#     935     features = self.extract_features(obs, self.features_extractor)
#     936 qvalue_input = th.cat([features, actions], dim=1)
# --> 937 return tuple(q_net(qvalue_input) for q_net in self.q_networks)
#
# File c:\Users\pablo\.conda\envs\rl23x\lib\site-packages\stable_baselines3\common\policies.py:937, in <genexpr>(.0)
#     935     features = self.extract_features(obs, self.features_extractor)
#     936 qvalue_input = th.cat([features, actions], dim=1)
# --> 937 return tuple(q_net(qvalue_input) for q_net in self.q_networks)
#
# File c:\Users\pablo\.conda\envs\rl23x\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\pablo\.conda\envs\rl23x\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\pablo\.conda\envs\rl23x\lib\site-packages\torch\nn\modules\container.py:215, in Sequential.forward(self, input)
#     213 def forward(self, input):
#     214     for module in self:
# --> 215         input = module(input)
#     216     return input
#
# File c:\Users\pablo\.conda\envs\rl23x\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\pablo\.conda\envs\rl23x\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\pablo\.conda\envs\rl23x\lib\site-packages\torch\nn\modules\linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %% [markdown]
# ## 4 - Exibe e Avalia o agente

# %%
record_video(ENVIRONMENT_ID, model, video_length=1000, prefix='ddpg-treinado')
show_videos('videos', prefix='ddpg-treinado')
# Out:
# Saving video to c:\Users\pablo\Documents\Projetos\pablo-sampaio\rl_facil\cap09\videos\alg-treinado-step-0-to-step-1000.mp4
# Moviepy - Building video c:\Users\pablo\Documents\Projetos\pablo-sampaio\rl_facil\cap09\videos\alg-treinado-step-0-to-step-1000.mp4.
# Moviepy - Writing video c:\Users\pablo\Documents\Projetos\pablo-sampaio\rl_facil\cap09\videos\alg-treinado-step-0-to-step-1000.mp4
# Moviepy - Done !
# Moviepy - video ready c:\Users\pablo\Documents\Projetos\pablo-sampaio\rl_facil\cap09\videos\alg-treinado-step-0-to-step-1000.mp4
# <video alt="videos\alg-treinado-step-0-to-step-1000.mp4" autoplay
#                     loop controls style="height: 400px;">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                 </video>

# %%
# Avalia o agente treinado
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=100)
print(f"Retorno médio: {mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# Retorno médio: -136.69 +/- 77.54
